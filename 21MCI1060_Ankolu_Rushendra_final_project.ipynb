# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
car=pd.read_csv('/content/quikr_car (1).csv')

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# ##### Creating backup copy

# %%
backup=car.copy()

# %% [markdown]
# ## Quality
#
# - names are pretty inconsistent
# - names have company names attached to it
# - some names are spam like 'Maruti Ertiga showroom condition with' and 'Well mentained Tata Sumo'
# - company: many of the names are not of any company like 'Used', 'URJENT', and so on.
# - year has many non-year values
# - year is in object. Change to integer
# - Price has Ask for Price
# - Price has commas in its prices and is in object
# - kms_driven has object values with kms at last.
# - It has nan values and two rows have 'Petrol' in them
# - fuel_type has nan values

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# #### year has many non-year values

# %%
car=car[car['year'].str.isnumeric()]

# %% [markdown]
# #### year is in object. Change to integer

# %%
car['year']=car['year'].astype(int)

# %% [markdown]
# #### Price has Ask for Price

# %%
car=car[car['Price']!='Ask For Price']

# %% [markdown]
# #### Price has commas in its prices and is in object

# %%
car['Price']=car['Price'].str.replace(',','').astype(int)

# %% [markdown]
# ####  kms_driven has object values with kms at last.

# %%
car['kms_driven']=car['kms_driven'].str.split().str.get(0).str.replace(',','')

# %% [markdown]
# #### It has nan values and two rows have 'Petrol' in them

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car['kms_driven']=car['kms_driven'].astype(int)

# %% [markdown]
# #### fuel_type has nan values

# %%
car=car[~car['fuel_type'].isna()]

# %%
car = pd.get_dummies(car, columns=['fuel_type'])

# %%
car.shape
# Out:
# (816, 8)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 816 entries, 0 to 889
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              816 non-null    object
#  1   company           816 non-null    object
#  2   year              816 non-null    int64
#  3   Price             816 non-null    int64
#  4   kms_driven        816 non-null    int64
#  5   fuel_type_Diesel  816 non-null    uint8
#  6   fuel_type_LPG     816 non-null    uint8
#  7   fuel_type_Petrol  816 non-null    uint8
# dtypes: int64(3), object(2), uint8(3)
# memory usage: 40.6+ KB

# %% [markdown]
# ### name and company had spammed data...but with the previous cleaning, those rows got removed.

# %% [markdown]
# #### Company does not need any cleaning now. Changing car names. Keeping only the first three words

# %%
car['name']=car['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %% [markdown]
# #### Resetting the index of the final cleaned data

# %%
car=car.reset_index(drop=True)

# %% [markdown]
# ## Cleaned Data

# %%
car
# Out:
#                        name   company  year   Price  kms_driven  \
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2         Hyundai Grand i10   Hyundai  2014  325000       28000
# 3    Ford EcoSport Titanium      Ford  2014  575000       36000
# 4                 Ford Figo      Ford  2012  175000       41000
# ..                      ...       ...   ...     ...         ...
# 811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812          Tata Indica V2      Tata  2009  110000       30000
# 813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814            Tata Zest XM      Tata  2018  260000       27000
# 815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#      fuel_type_Diesel  fuel_type_LPG  fuel_type_Petrol
# 0                   0              0                 1
# 1                   1              0                 0
# ...

# %%
car.to_csv('Cleaned_Car_data.csv')

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              816 non-null    object
#  1   company           816 non-null    object
#  2   year              816 non-null    int64
#  3   Price             816 non-null    int64
#  4   kms_driven        816 non-null    int64
#  5   fuel_type_Diesel  816 non-null    uint8
#  6   fuel_type_LPG     816 non-null    uint8
#  7   fuel_type_Petrol  816 non-null    uint8
# dtypes: int64(3), object(2), uint8(3)
# memory usage: 34.4+ KB

# %%
car.describe(include='all')
# Out:
#                        name company         year         Price     kms_driven  \
# count                   816     816   816.000000  8.160000e+02     816.000000
# unique                  254      25          NaN           NaN            NaN
# top     Maruti Suzuki Swift  Maruti          NaN           NaN            NaN
# freq                     51     221          NaN           NaN            NaN
# mean                    NaN     NaN  2012.444853  4.117176e+05   46275.531863
# std                     NaN     NaN     4.002992  4.751844e+05   34297.428044
# min                     NaN     NaN  1995.000000  3.000000e+04       0.000000
# 25%                     NaN     NaN  2010.000000  1.750000e+05   27000.000000
# 50%                     NaN     NaN  2013.000000  2.999990e+05   41000.000000
# 75%                     NaN     NaN  2015.000000  4.912500e+05   56818.500000
# max                     NaN     NaN  2019.000000  8.500003e+06  400000.000000
#
# ...

# %%
car=car[car['Price']<6000000]

# %% [markdown]
# ### Checking relationship of Company with Price

# %%
car['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Ford', 'Maruti', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat', 'Force',
#        'Mercedes', 'Land', 'Jaguar', 'Jeep', 'Volvo'], dtype=object)

# %%
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# ### Checking relationship of Year with Price

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# ### Checking relationship of kms_driven with Price

# %%
sns.relplot(x='kms_driven',y='Price',data=car,height=7,aspect=1.5)

# %% [markdown]
# ### Checking relationship of Fuel Type with Price

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type_LPG',y='Price',data=car)
# Out:
# <Axes: xlabel='fuel_type_LPG', ylabel='Price'>

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type_Petrol',y='Price',data=car)
# Out:
# <Axes: xlabel='fuel_type_Petrol', ylabel='Price'>

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type_Diesel',y='Price',data=car)
# Out:
# <Axes: xlabel='fuel_type_Diesel', ylabel='Price'>

# %% [markdown]
# ### Relationship of Price with FuelType, Year and Company mixed

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type_Petrol',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type_LPG',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='fuel_type_Diesel',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# ### Extracting Training Data

# %%
X=car[['name','company','year','kms_driven','fuel_type_LPG', 'fuel_type_Petrol', 'fuel_type_Diesel']]
y=car['Price']

# %%
X
# Out:
#                        name   company  year  kms_driven  fuel_type_LPG  \
# 0       Hyundai Santro Xing   Hyundai  2007       45000              0
# 1       Mahindra Jeep CL550  Mahindra  2006          40              0
# 2         Hyundai Grand i10   Hyundai  2014       28000              0
# 3    Ford EcoSport Titanium      Ford  2014       36000              0
# 4                 Ford Figo      Ford  2012       41000              0
# ..                      ...       ...   ...         ...            ...
# 811      Maruti Suzuki Ritz    Maruti  2011       50000              0
# 812          Tata Indica V2      Tata  2009       30000              0
# 813    Toyota Corolla Altis    Toyota  2009      132000              0
# 814            Tata Zest XM      Tata  2018       27000              0
# 815      Mahindra Quanto C8  Mahindra  2013       40000              0
#
#      fuel_type_Petrol  fuel_type_Diesel
# 0                   1                 0
# ...

# %%
y.shape
# Out:
# (815,)

# %% [markdown]
# ### Applying Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %% [markdown]
# #### Creating an OneHotEncoder object to contain all the possible categories

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company']])
# Out:
# OneHotEncoder()

# %% [markdown]
# #### Creating a column transformer to transform categorical columns

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company']),
                                    remainder='passthrough')

# %% [markdown]
# #### Linear Regression Model

# %%
lr=LinearRegression()

# %% [markdown]
# #### Making a pipeline

# %%
pipe=make_pipeline(column_trans,lr)

# %% [markdown]
# #### Fitting the  model

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#        'Volkswagen Vento Konekt', 'Volvo S80 Summum'], dtype=object),
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object)]),
# ...

# %%
y_pred=pipe.predict(X_test)

# %% [markdown]
# #### Checking R2 Score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6235243309667214

# %% [markdown]
# #### Finding the model with a random state of TrainTestSplit where the model was found to give almost 0.92 as r2_score

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 302

# %%
scores[np.argmax(scores)]
# Out:
# 0.8991173377015573

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,0,1,0]).reshape(1,7)))
# Out:
# array([430149.47850607])

# %% [markdown]
# #### The best model is found at a certain random state

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8991173377015573

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type_Diesel','fuel_type_LPG','fuel_type_Petrol'],
                          data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,0,0,1]).reshape(1,7)))
# Out:
# array([456612.37414055])

# %%
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#        'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#        'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#        'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#        'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#        'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#        'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#        'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#        'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...
